# %%
# !pip install mlxtend

import numpy as np
import pandas as pd
import seaborn as sns


from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

from mlxtend.preprocessing import TransactionEncoder

# %%
basketData = pd.read_csv('clean.csv')

# %%
trans = basketData.groupby(['InvoiceNo'])['Description'].apply(list).values.tolist()

trans
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-dff8078e4d32> in <module>
# ----> 1 trans = basketData.groupby(['InvoiceNo'])['Description'].apply(list).values.tolist()
#       2
#       3 trans
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'InvoiceNo'

# %%
te = TransactionEncoder()
te_ary = te.fit(trans).transform(trans)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        *Boombox Ipod Classic  *USB Office Mirror Ball  10 COLOUR SPACEBOY PEN  \
# 0                      False                    False                   False
# 1                      False                    False                   False
# 2                      False                    False                   False
# 3                      False                    False                   False
# 4                      False                    False                   False
# ...                      ...                      ...                     ...
# 20091                  False                    False                   False
# 20092                  False                    False                   False
# 20093                  False                    False                   False
# 20094                  False                    False                   False
# 20095                  False                    False                   False
#
#        12 COLOURED PARTY BALLOONS  12 DAISY PEGS IN WOOD BOX  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ...                           ...                        ...
# 20091                       False                      False
# 20092                       False                      False
# 20093                       False                      False
# 20094                       False                      False
# 20095                       False                      False
#
#        12 EGG HOUSE PAINTED WOOD  12 HANGING EGGS HAND PAINTED  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 20091                      False                         False
# 20092                      False                         False
# 20093                      False                         False
# 20094                      False                         False
# 20095                      False                         False
#
#        12 IVORY ROSE PEG PLACE SETTINGS  12 MESSAGE CARDS WITH ENVELOPES  \
# 0                                 False                            False
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
# ...                                 ...                              ...
# 20091                             False                            False
# 20092                             False                            False
# 20093                             False                            False
# 20094                             False                            False
# 20095                             False                            False
#
#        12 PENCIL SMALL TUBE WOODLAND  ...  michel oops  on cargo order  \
# 0                              False  ...        False           False
# 1                              False  ...        False           False
# 2                              False  ...        False           False
# 3                              False  ...        False           False
# 4                              False  ...        False           False
# ...                              ...  ...          ...             ...
# 20091                          False  ...        False           False
# 20092                          False  ...        False           False
# 20093                          False  ...        False           False
# 20094                          False  ...        False           False
# 20095                          False  ...        False           False
#
#        rcvd be air temp fix for dotcom sit   test  \
# 0                                    False  False
# 1                                    False  False
# 2                                    False  False
# 3                                    False  False
# 4                                    False  False
# ...                                    ...    ...
# 20091                                False  False
# 20092                                False  False
# 20093                                False  False
# 20094                                False  False
# 20095                                False  False
#
#        to push order througha s stock was  website fixed  wrongly coded 20713  \
# 0                                   False          False                False
# 1                                   False          False                False
# 2                                   False          False                False
# 3                                   False          False                False
# 4                                   False          False                False
# ...                                   ...            ...                  ...
# 20091                               False          False                False
# 20092                               False          False                False
# 20093                               False          False                False
# 20094                               False          False                False
# 20095                               False          False                False
#
#        wrongly coded 23343  wrongly marked  wrongly marked 23343
# 0                    False           False                 False
# 1                    False           False                 False
# 2                    False           False                 False
# 3                    False           False                 False
# 4                    False           False                 False
# ...                    ...             ...                   ...
# 20091                False           False                 False
# 20092                False           False                 False
# 20093                False           False                 False
# 20094                False           False                 False
# 20095                False           False                 False
#
# [20096 rows x 4050 columns]

# %%
frequent_itemsets = apriori(df, min_support=0.02, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#                                            antecedents  \
# 0                        (60 TEATIME FAIRY CAKE CASES)
# 1                    (PACK OF 72 RETROSPOT CAKE CASES)
# 2                         (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE PINK)
# 4                         (ALARM CLOCK BAKELIKE GREEN)
# ..                                                 ...
# 171  (JUMBO BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)
# 172  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)
# 173                          (JUMBO BAG PINK POLKADOT)
# 174                          (JUMBO BAG RED RETROSPOT)
# 175                           (JUMBO STORAGE BAG SUKI)
#
#                                            consequents  antecedent support  \
# 0                    (PACK OF 72 RETROSPOT CAKE CASES)            0.041202
# 1                        (60 TEATIME FAIRY CAKE CASES)            0.065685
# 2                          (ALARM CLOCK BAKELIKE PINK)            0.048766
# 3                         (ALARM CLOCK BAKELIKE GREEN)            0.038963
# 4                           (ALARM CLOCK BAKELIKE RED)            0.048766
# ..                                                 ...                 ...
# 171                          (JUMBO BAG RED RETROSPOT)            0.025627
# 172                          (JUMBO BAG PINK POLKADOT)            0.036027
# 173  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)            0.060609
# 174  (JUMBO BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)            0.104100
# 175  (JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROS...            0.058917
#
#      consequent support   support  confidence       lift  leverage  conviction
# 0              0.065685  0.022542    0.547101   8.329205  0.019835    2.062968
# 1              0.041202  0.022542    0.343182   8.329205  0.019835    1.459761
# 2              0.038963  0.020800    0.426531  10.947074  0.018900    1.675830
# 3              0.048766  0.020800    0.533844  10.947074  0.018900    2.040593
# 4              0.052299  0.031847    0.653061  12.487077  0.029297    2.731609
# ..                  ...       ...         ...        ...       ...         ...
# 171            0.104100  0.020551    0.801942   7.703547  0.017884    4.523415
# 172            0.060609  0.020551    0.570442   9.411824  0.018368    2.186878
# 173            0.036027  0.020551    0.339080   9.411824  0.018368    1.458533
# 174            0.025627  0.020551    0.197419   7.703547  0.017884    1.214049
# 175            0.041053  0.020551    0.348818   8.496773  0.018133    1.472624
#
# [176 rows x 9 columns]

# %%
rules.sort_values(by=['support','confidence'], ascending=False)
# Out:
#                               antecedents  \
# 48              (JUMBO BAG PINK POLKADOT)
# 49              (JUMBO BAG RED RETROSPOT)
# 29      (GREEN REGENCY TEACUP AND SAUCER)
# 28      (ROSES REGENCY TEACUP AND SAUCER)
# 75               (JUMBO STORAGE BAG SUKI)
# ..                                    ...
# 155  (WHITE HANGING HEART T-LIGHT HOLDER)
# 45                      (JUMBO BAG PEARS)
# 152            (STRAWBERRY CHARLOTTE BAG)
# 153              (WOODLAND CHARLOTTE BAG)
# 44                     (JUMBO BAG APPLES)
#
#                              consequents  antecedent support  \
# 48             (JUMBO BAG RED RETROSPOT)            0.060609
# 49             (JUMBO BAG PINK POLKADOT)            0.104100
# 29     (ROSES REGENCY TEACUP AND SAUCER)            0.050508
# 28     (GREEN REGENCY TEACUP AND SAUCER)            0.053045
# 75             (JUMBO BAG RED RETROSPOT)            0.058917
# ..                                   ...                 ...
# 155  (WOODEN PICTURE FRAME WHITE FINISH)            0.112460
# 45                    (JUMBO BAG APPLES)            0.029608
# 152             (WOODLAND CHARLOTTE BAG)            0.035928
# 153           (STRAWBERRY CHARLOTTE BAG)            0.041551
# 44                     (JUMBO BAG PEARS)            0.048666
#
#      consequent support   support  confidence       lift  leverage  conviction
# 48             0.104100  0.041053    0.677340   6.506607  0.034744    2.776605
# 49             0.060609  0.041053    0.394359   6.506607  0.034744    1.551070
# 29             0.053045  0.038217    0.756650  14.264206  0.035537    3.891332
# 28             0.050508  0.038217    0.720450  14.264206  0.035537    3.396507
# 75             0.104100  0.036027    0.611486   5.874012  0.029894    2.305968
# ..                  ...       ...         ...        ...       ...         ...
# 155            0.054737  0.020303    0.180531   3.298137  0.014147    1.153506
# 45             0.048666  0.020203    0.682353  14.021027  0.018762    2.994939
# 152            0.041551  0.020203    0.562327  13.533558  0.018710    2.189875
# 153            0.035928  0.020203    0.486228  13.533558  0.018710    1.876458
# 44             0.029608  0.020203    0.415133  14.021027  0.018762    1.659167
#
# [176 rows x 9 columns]
